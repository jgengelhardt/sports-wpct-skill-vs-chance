# %%
import requests
import json
from math import sqrt
from statistics import stdev
from statistics import variance

# %%
# get
league_request = requests.get('https://records.nhl.com/site/api/franchise-season-results')
league_json = league_request.json()
NHL_alltime = league_json['data']
print('Loaded NHL franchise season results')
# Out:
# Loaded NHL franchise season results

# %%
def get_season(league,startyear):
    # only include franchise records from a given season
    yearid = int(f"{startyear}{startyear+1}")
    season_teams = []
    for element in league:
        if element['seasonId'] == yearid:
            season_teams.append(element)
    print(f'Found {len(season_teams)} entries with seasonId {yearid}')
    # only include regular season games
    filtered_teams = []
    for team in season_teams:
        if team['gamesPlayed'] == season_teams[0]['gamesPlayed']:
            filtered_teams.append(team)
    print(f'Removed {len(season_teams)-len(filtered_teams)} entries, leaving {len(filtered_teams)} from the regular season')
    return filtered_teams

# %%
def var_skill(season_teams):
    if len(season_teams) >= 2:
        season_wpercentages = []
        for team in season_teams: # find the variance of win/loss records in a league
            season_wpercentages.append((team['wins']+(team['ties'] or 0)/2) / team['gamesPlayed'])
        # compare the observed variance to chance
        var_diff = variance(season_wpercentages) - (.5*.5/season_teams[0]['gamesPlayed'])
        if var_diff > 0:
            return round(sqrt(var_diff),3)
        else:
            return 'Error'
    else:
        print('Not enough season participation')

# %%
def skill_history(start, stop):
    output = {'year': 'skill stdev'}
    for i in range(start,stop+1):
        output[i] = var_skill(get_season(NHL_alltime,i))
    return output
        
print(skill_history(1900,2020))
# Out:
# Found 0 entries with seasonId 19001901
# Removed 0 entries, leaving 0 from the regular season
# Not enough season participation
# Found 0 entries with seasonId 19011902
# Removed 0 entries, leaving 0 from the regular season
# Not enough season participation
# Found 0 entries with seasonId 19021903
# Removed 0 entries, leaving 0 from the regular season
# Not enough season participation
# Found 0 entries with seasonId 19031904
# Removed 0 entries, leaving 0 from the regular season
# Not enough season participation
# Found 0 entries with seasonId 19041905
# Removed 0 entries, leaving 0 from the regular season
# Not enough season participation
# Found 0 entries with seasonId 19051906
# Removed 0 entries, leaving 0 from the regular season
# Not enough season participation
# Found 0 entries with seasonId 19061907
# Removed 0 entries, leaving 0 from the regular season
# Not enough season participation
# Found 0 entries with seasonId 19071908
# Removed 0 entries, leaving 0 from the regular season
# Not enough season participation
# Found 0 entries with seasonId 19081909
# Removed 0 entries, leaving 0 from the regular season
# Not enough season participation
# Found 0 entries with seasonId 19091910
# Removed 0 entries, leaving 0 from the regular season
# Not enough season participation
# Found 0 entries with seasonId 19101911
# Removed 0 entries, leaving 0 from the regular season
# Not enough season participation
# Found 0 entries with seasonId 19111912
# Removed 0 entries, leaving 0 from the regular season
# Not enough season participation
# Found 0 entries with seasonId 19121913
# Removed 0 entries, leaving 0 from the regular season
# Not enough season participation
# Found 0 entries with seasonId 19131914
# Removed 0 entries, leaving 0 from the regular season
# Not enough season participation
# Found 0 entries with seasonId 19141915
# Removed 0 entries, leaving 0 from the regular season
# Not enough season participation
# Found 0 entries with seasonId 19151916
# Removed 0 entries, leaving 0 from the regular season
# Not enough season participation
# Found 0 entries with seasonId 19161917
# Removed 0 entries, leaving 0 from the regular season
# Not enough season participation
# Found 6 entries with seasonId 19171918
# Removed 3 entries, leaving 3 from the regular season
# Found 5 entries with seasonId 19181919
# Removed 2 entries, leaving 3 from the regular season
# Found 5 entries with seasonId 19191920
# Removed 1 entries, leaving 4 from the regular season
# Found 6 entries with seasonId 19201921
# Removed 2 entries, leaving 4 from the regular season
# Found 6 entries with seasonId 19211922
# Removed 2 entries, leaving 4 from the regular season
# Found 6 entries with seasonId 19221923
# Removed 2 entries, leaving 4 from the regular season
# Found 6 entries with seasonId 19231924
# Removed 2 entries, leaving 4 from the regular season
# Found 8 entries with seasonId 19241925
# Removed 2 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19251926
# Removed 3 entries, leaving 7 from the regular season
# Found 16 entries with seasonId 19261927
# Removed 6 entries, leaving 10 from the regular season
# Found 16 entries with seasonId 19271928
# Removed 6 entries, leaving 10 from the regular season
# Found 16 entries with seasonId 19281929
# Removed 6 entries, leaving 10 from the regular season
# Found 16 entries with seasonId 19291930
# Removed 6 entries, leaving 10 from the regular season
# Found 16 entries with seasonId 19301931
# Removed 6 entries, leaving 10 from the regular season
# Found 14 entries with seasonId 19311932
# Removed 6 entries, leaving 8 from the regular season
# Found 15 entries with seasonId 19321933
# Removed 6 entries, leaving 9 from the regular season
# Found 15 entries with seasonId 19331934
# Removed 6 entries, leaving 9 from the regular season
# Found 15 entries with seasonId 19341935
# Removed 6 entries, leaving 9 from the regular season
# Found 14 entries with seasonId 19351936
# Removed 6 entries, leaving 8 from the regular season
# Found 14 entries with seasonId 19361937
# Removed 6 entries, leaving 8 from the regular season
# Found 14 entries with seasonId 19371938
# Removed 6 entries, leaving 8 from the regular season
# Found 13 entries with seasonId 19381939
# Removed 6 entries, leaving 7 from the regular season
# Found 13 entries with seasonId 19391940
# Removed 6 entries, leaving 7 from the regular season
# Found 13 entries with seasonId 19401941
# Removed 6 entries, leaving 7 from the regular season
# Found 13 entries with seasonId 19411942
# Removed 6 entries, leaving 7 from the regular season
# Found 10 entries with seasonId 19421943
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19431944
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19441945
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19451946
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19461947
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19471948
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19481949
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19491950
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19501951
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19511952
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19521953
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19531954
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19541955
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19551956
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19561957
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19571958
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19581959
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19591960
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19601961
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19611962
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19621963
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19631964
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19641965
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19651966
# Removed 4 entries, leaving 6 from the regular season
# Found 10 entries with seasonId 19661967
# Removed 4 entries, leaving 6 from the regular season
# Found 20 entries with seasonId 19671968
# Removed 8 entries, leaving 12 from the regular season
# Found 20 entries with seasonId 19681969
# Removed 8 entries, leaving 12 from the regular season
# Found 20 entries with seasonId 19691970
# Removed 8 entries, leaving 12 from the regular season
# Found 22 entries with seasonId 19701971
# Removed 8 entries, leaving 14 from the regular season
# Found 22 entries with seasonId 19711972
# Removed 8 entries, leaving 14 from the regular season
# Found 24 entries with seasonId 19721973
# Removed 8 entries, leaving 16 from the regular season
# Found 24 entries with seasonId 19731974
# Removed 8 entries, leaving 16 from the regular season
# Found 30 entries with seasonId 19741975
# Removed 12 entries, leaving 18 from the regular season
# Found 30 entries with seasonId 19751976
# Removed 12 entries, leaving 18 from the regular season
# Found 30 entries with seasonId 19761977
# Removed 12 entries, leaving 18 from the regular season
# Found 30 entries with seasonId 19771978
# Removed 12 entries, leaving 18 from the regular season
# Found 29 entries with seasonId 19781979
# Removed 12 entries, leaving 17 from the regular season
# Found 37 entries with seasonId 19791980
# Removed 16 entries, leaving 21 from the regular season
# Found 37 entries with seasonId 19801981
# Removed 16 entries, leaving 21 from the regular season
# Found 37 entries with seasonId 19811982
# Removed 16 entries, leaving 21 from the regular season
# Found 37 entries with seasonId 19821983
# Removed 16 entries, leaving 21 from the regular season
# Found 37 entries with seasonId 19831984
# Removed 16 entries, leaving 21 from the regular season
# Found 37 entries with seasonId 19841985
# Removed 16 entries, leaving 21 from the regular season
# Found 37 entries with seasonId 19851986
# Removed 16 entries, leaving 21 from the regular season
# Found 37 entries with seasonId 19861987
# Removed 16 entries, leaving 21 from the regular season
# Found 37 entries with seasonId 19871988
# Removed 16 entries, leaving 21 from the regular season
# Found 37 entries with seasonId 19881989
# Removed 16 entries, leaving 21 from the regular season
# Found 37 entries with seasonId 19891990
# Removed 16 entries, leaving 21 from the regular season
# Found 37 entries with seasonId 19901991
# Removed 16 entries, leaving 21 from the regular season
# Found 38 entries with seasonId 19911992
# Removed 16 entries, leaving 22 from the regular season
# Found 40 entries with seasonId 19921993
# Removed 16 entries, leaving 24 from the regular season
# Found 42 entries with seasonId 19931994
# Removed 16 entries, leaving 26 from the regular season
# Found 42 entries with seasonId 19941995
# Removed 16 entries, leaving 26 from the regular season
# Found 42 entries with seasonId 19951996
# Removed 16 entries, leaving 26 from the regular season
# Found 42 entries with seasonId 19961997
# Removed 16 entries, leaving 26 from the regular season
# Found 42 entries with seasonId 19971998
# Removed 16 entries, leaving 26 from the regular season
# Found 43 entries with seasonId 19981999
# Removed 16 entries, leaving 27 from the regular season
# Found 44 entries with seasonId 19992000
# Removed 16 entries, leaving 28 from the regular season
# Found 46 entries with seasonId 20002001
# Removed 16 entries, leaving 30 from the regular season
# Found 46 entries with seasonId 